# %% [markdown]
# ## Get weather data and vegetation data from API's

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('RDS-2013-0009.5_SQLITE/Data/fires.csv')
# Out:
# /Users/padmaprabagaran/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (0,7,9,10,11,12,13,14,15,16,17,24,25,34,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.columns
# Out:
# Index(['FOD_ID', 'FPA_ID', 'SOURCE_SYSTEM_TYPE', 'SOURCE_SYSTEM',
#        'NWCG_REPORTING_AGENCY', 'NWCG_REPORTING_UNIT_ID',
#        'NWCG_REPORTING_UNIT_NAME', 'SOURCE_REPORTING_UNIT',
#        'SOURCE_REPORTING_UNIT_NAME', 'LOCAL_FIRE_REPORT_ID',
#        'LOCAL_INCIDENT_ID', 'FIRE_CODE', 'FIRE_NAME',
#        'ICS_209_PLUS_INCIDENT_JOIN_ID', 'ICS_209_PLUS_COMPLEX_JOIN_ID',
#        'MTBS_ID', 'MTBS_FIRE_NAME', 'COMPLEX_NAME', 'FIRE_YEAR',
#        'DISCOVERY_DATE', 'DISCOVERY_DOY', 'DISCOVERY_TIME',
#        'NWCG_CAUSE_CLASSIFICATION', 'NWCG_GENERAL_CAUSE',
#        'NWCG_CAUSE_AGE_CATEGORY', 'CONT_DATE', 'CONT_DOY', 'CONT_TIME',
#        'FIRE_SIZE', 'FIRE_SIZE_CLASS', 'LATITUDE', 'LONGITUDE', 'OWNER_DESCR',
#        'STATE', 'COUNTY', 'FIPS_CODE', 'FIPS_NAME'],
#       dtype='object')

# %%
# drop all rows besides the ones below and remove all rows with missing values
df = df.dropna(subset=['LATITUDE','LONGITUDE','FIRE_SIZE_CLASS','FIRE_SIZE','CONT_TIME'])
df = df[['NWCG_REPORTING_UNIT_NAME','FIRE_YEAR','DISCOVERY_DATE', 'DISCOVERY_DOY', 'DISCOVERY_TIME',
       'NWCG_CAUSE_CLASSIFICATION', 'NWCG_GENERAL_CAUSE', 'CONT_DATE', 'CONT_DOY', 'CONT_TIME',
       'FIRE_SIZE', 'FIRE_SIZE_CLASS', 'LATITUDE', 'LONGITUDE', 'OWNER_DESCR',
       'STATE']]
df = df.drop_duplicates()

# %%
# Number of data points in the data set
# 1232108
len(df)
# Out:
# 1232108

# %%
df
# Out:
#                  NWCG_REPORTING_UNIT_NAME  FIRE_YEAR   DISCOVERY_DATE  \
# 0                  Plumas National Forest     2005.0    2/2/2005 0:00
# 1                Eldorado National Forest     2004.0   5/12/2004 0:00
# 2                Eldorado National Forest     2004.0   5/31/2004 0:00
# 3                Eldorado National Forest     2004.0   6/28/2004 0:00
# 4                Eldorado National Forest     2004.0   6/28/2004 0:00
# ...                                   ...        ...              ...
# 2166694  Connecticut Division of Forestry     2018.0  11/17/2018 0:00
# 2166695  Connecticut Division of Forestry     2018.0  12/12/2018 0:00
# 2166696  Connecticut Division of Forestry     2018.0   4/16/2018 0:00
# 2166697  Connecticut Division of Forestry     2018.0   4/23/2018 0:00
# 2166698  Connecticut Division of Forestry     2018.0   11/9/2018 0:00
#
#          DISCOVERY_DOY  DISCOVERY_TIME NWCG_CAUSE_CLASSIFICATION  \
# ...

# %%
sample = df.sample(n=100, random_state=5)
sample
# Out:
#                                 NWCG_REPORTING_UNIT_NAME  FIRE_YEAR  \
# 1276254  Pennsylvania Division of Forest Fire Protection     2003.0
# 80084                            Angeles National Forest     1995.0
# 8518                               Tonto National Forest     2006.0
# 753800           Utah Division Forestry Fire State Lands     2001.0
# 1486708                      Georgia Forestry Commission     2011.0
# ...                                                  ...        ...
# 1279212               New Mexico State Forestry Division     2009.0
# 96046                            Chugach National Forest     1996.0
# 1305557                      Fire Department of New York     2006.0
# 406942                            Florida Forest Service     2004.0
# 325918                Northwest District, Grand Junction     2008.0
#
#          DISCOVERY_DATE  DISCOVERY_DOY  DISCOVERY_TIME  \
# 1276254  3/25/2003 0:00           84.0          1323.0
# ...

# %%
sample.to_csv('data.csv',index=False)

# %%
from datetime import date, timedelta
d = ['6', '15', '2010']
DATE = date(int(d[2]), 8,1).isoformat()
DATE_1 = date.fromisoformat(DATE) - timedelta(days=1)
print(DATE, DATE_1)
type(DATE_1)
# Out:
# 2010-08-01 2010-07-31
# datetime.date

# %%
import urllib.parse
import urllib.request
import json
import time
import matplotlib.pyplot as plt
import pandas as pd
from datetime import date, timedelta

API_KEY="9RU5D8QRGNPSUAYVYVZAP5HP6"
LOCATION=""
DATE=""
UNIT_GROUP="us"

for x in range(0,len(sample)):
    LOCATION=str(sample.iloc[x].LATITUDE) +','+ str(sample.iloc[x].LONGITUDE)
    DATE=str(sample.iloc[x].DISCOVERY_DATE)[:-5]
    date = DATE.split('/')
    print(date)
    print(date[0])
    day = int(date[1])
    month = int(date[0])
    year = int(date[2])
    print(type(day))
    DATE= date(year,month,day).isoformat()
    DATE_1 = str(date.fromisoformat(DATE) - timedelta(days=1))
    DATE_3 = str(date.fromisoformat(DATE) - timedelta(days=3))
    DATE_5 = str(date.fromisoformat(DATE) - timedelta(days=5))

    print(DATE, DATE_1, DATE_3, DATE_5)
# Out:
# ['9', '3', '1995']
# 9
# <class 'int'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-96-35ee04d3c7a0> in <module>
#      22     year = int(date[2])
#      23     print(type(day))
# ---> 24     DATE= date(year,month,day).isoformat()
#      25     DATE_1 = str(date.fromisoformat(DATE) - timedelta(days=1))
#      26     DATE_3 = str(date.fromisoformat(DATE) - timedelta(days=3))
#
# TypeError: 'list' object is not callable

# %%
def getWeatherForecastOnDay():
         requestUrl = "https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/" + LOCATION
         requestUrl = requestUrl+"?key="+API_KEY+"&unitGroup="+UNIT_GROUP+"&include=days";
         
         print('Weather requestUrl={requestUrl}'.format(requestUrl=requestUrl))

         try:
                 req = urllib.request.urlopen(requestUrl)
         except:
                 print("Could not read from:"+requestUrl);
                 return []
                
         rawForecastData = req.read()
         req.close()
         return json.loads(rawForecastData)

def getWeatherForecastOneDay():
         requestUrl = "https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/" + urllib.parse.quote_plus(LOCATION)
         requestUrl = requestUrl+"?key="+API_KEY+"&unitGroup="+UNIT_GROUP+"&include=days";
         
         print('Weather requestUrl={requestUrl}'.format(requestUrl=requestUrl))

         try:
                 req = urllib.request.urlopen(requestUrl)
         except:
                 print("Could not read from:"+requestUrl);
                 return []
                
         rawForecastData = req.read()
         req.close()
         return json.loads(rawForecastData)
    
def getWeatherForecastTwoDay():
         requestUrl = "https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/" + urllib.parse.quote_plus(LOCATION)
         requestUrl = requestUrl+"?key="+API_KEY+"&unitGroup="+UNIT_GROUP+"&include=days";
         
         print('Weather requestUrl={requestUrl}'.format(requestUrl=requestUrl))

         try:
                 req = urllib.request.urlopen(requestUrl)
         except:
                 print("Could not read from:"+requestUrl);
                 return []
                
         rawForecastData = req.read()
         req.close()
         return json.loads(rawForecastData)
    
def getWeatherForecastThreeDay():
         requestUrl = "https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/" + urllib.parse.quote_plus(LOCATION)
         requestUrl = requestUrl+"?key="+API_KEY+"&unitGroup="+UNIT_GROUP+"&include=days";
         
         print('Weather requestUrl={requestUrl}'.format(requestUrl=requestUrl))

         try:
                 req = urllib.request.urlopen(requestUrl)
         except:
                 print("Could not read from:"+requestUrl);
                 return []
                
         rawForecastData = req.read()
         req.close()
         return json.loads(rawForecastData)

# %%
weatherForecast = getWeatherForecast()

print('Weather forecast for {location}'.format(location=weatherForecast['resolvedAddress']))
days=weatherForecast['days'];

for day in days:
    print('{datetime} tempmax:{tempmax} tempmin:{tempmin} description:{description}'.format(datetime=day['datetime'], 
                                                                                            tempmax=day["tempmax"], 
                                                                                            tempmin=day["tempmin"], 
                                                                                            description=day["description"]))

# %%
## look into a heatmap of dates to see which times of the years had most fires by category and whole

# %%
# Out:
# 50

# %%
import requests
import json
import io

url = "https://visual-crossing-weather.p.rapidapi.com/history"

# 1 day before
querystring = {"startDateTime":"2016-07-24T15:11:00","aggregateHours":"24","location":"40.00310,-102.194900","endDateTime":"2016-07-25T15:11:00","unitGroup":"us","dayStartTime":"8:00:00","contentType":"csv","dayEndTime":"17:00:00","shortColumnNames":"0"}

headers = {"X-RapidAPI-Host": "visual-crossing-weather.p.rapidapi.com",
           "X-RapidAPI-Key": "49d7e1d220mshfcb1e530dedd8b9p1630c8jsnb6e65e773bf6"}

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
response.raw
# Out:
# Address,Date time,Minimum Temperature,Maximum Temperature,Temperature,Dew Point,Relative Humidity,Heat Index,Wind Speed,Wind Gust,Wind Direction,Wind Chill,Precipitation,Precipitation Cover,Snow Depth,Visibility,Cloud Cover,Sea Level Pressure,Weather Type,Latitude,Longitude,Resolved Address,Name,Info,Conditions
# "40.00310,-102.194900","07/24/2016",63.0,91.2,74.6,57.4,59.32,89.3,20.3,33.3,213.2,,0.43,30.0,,9.3,32.7,1017.2,"Lightning Without Thunder, Thunderstorm, Light Rain",40.0031,-102.1949,"40.00310,-102.194900","40.00310,-102.194900","","Rain, Partially cloudy"

# %%
rawData = pd.read_csv(io.StringIO(response.text))
rawData
# Out:
#                 Address   Date time  Minimum Temperature  Maximum Temperature  \
# 0  40.00310,-102.194900  07/24/2016                 63.0                 91.2
#
#    Temperature  Dew Point  Relative Humidity  Heat Index  Wind Speed  \
# 0         74.6       57.4              59.32        89.3        20.3
#
#    Wind Gust  ...  Visibility  Cloud Cover  Sea Level Pressure  \
# 0       33.3  ...         9.3         32.7              1017.2
#
#                                         Weather Type  Latitude  Longitude  \
# 0  Lightning Without Thunder, Thunderstorm, Light...   40.0031  -102.1949
#
#        Resolved Address                  Name Info              Conditions
# 0  40.00310,-102.194900  40.00310,-102.194900  NaN  Rain, Partially cloudy
#
# [1 rows x 25 columns]

# %%
# 2 days before 
querystring = {"startDateTime":"2016-07-23T15:11:00","aggregateHours":"24","location":"40.00310,-102.194900","endDateTime":"2016-07-24T15:11:00","unitGroup":"us","dayStartTime":"8:00:00","contentType":"csv","dayEndTime":"17:00:00","shortColumnNames":"0"}

headers = {"X-RapidAPI-Host": "visual-crossing-weather.p.rapidapi.com",
           "X-RapidAPI-Key": "49d7e1d220mshfcb1e530dedd8b9p1630c8jsnb6e65e773bf6"}

response = requests.request("GET", url, headers=headers, params=querystring)

# %%
tup = pd.read_csv(io.StringIO(response.text))
rawData = rawData.append(tup)

# %%
# 3 days before 
querystring = {"startDateTime":"2016-07-22T15:11:00","aggregateHours":"24","location":"40.00310,-102.194900","endDateTime":"2016-07-23T15:11:00","unitGroup":"us","dayStartTime":"8:00:00","contentType":"csv","dayEndTime":"17:00:00","shortColumnNames":"0"}

headers = {"X-RapidAPI-Host": "visual-crossing-weather.p.rapidapi.com",
           "X-RapidAPI-Key": "49d7e1d220mshfcb1e530dedd8b9p1630c8jsnb6e65e773bf6"}

response = requests.request("GET", url, headers=headers, params=querystring)

tup = pd.read_csv(io.StringIO(response.text))
rawData = rawData.append(tup)

# %%
rawData
# Out:
#                 Address   Date time  Minimum Temperature  Maximum Temperature  \
# 0  40.00310,-102.194900  07/24/2016                 63.0                 91.2
# 0  40.00310,-102.194900  07/23/2016                 77.0                100.3
# 0  40.00310,-102.194900  07/22/2016                 70.0                101.1
#
#    Temperature  Dew Point  Relative Humidity  Heat Index  Wind Speed  \
# 0         74.6       57.4              59.32        89.3        20.3
# 0         86.7       51.6              33.42        95.7        15.7
# 0         84.2       61.6              52.77        98.8        16.1
#
#    Wind Gust  ...  Visibility  Cloud Cover  Sea Level Pressure  \
# 0       33.3  ...         9.3         32.7              1017.2
# 0       27.5  ...         9.9          1.7              1010.2
# 0       46.0  ...         9.8         37.1              1011.3
#
#                                         Weather Type  Latitude  Longitude  \
# ...

# %%
# Split the data set by size categories

# df_A = df[df["FIRE_SIZE_CLASS"] == 'A']
# df_B = df[df["FIRE_SIZE_CLASS"] == 'B']
# df_C = df[df["FIRE_SIZE_CLASS"] == 'C']
# df_D = df[df["FIRE_SIZE_CLASS"] == 'D']
# df_E = df[df["FIRE_SIZE_CLASS"] == 'E']
# df_F = df[df["FIRE_SIZE_CLASS"] == 'F']
# df_G = df[df["FIRE_SIZE_CLASS"] == 'G']

# df.NWCG_CAUSE_CLASSIFICATION.unique()
# df.NWCG_GENERAL_CAUSE.unique()
